# %%
# %load_ext autoreload
# %autoreload 2

import sys 
from os import getcwd, path
sys.path.append(path.dirname(getcwd()))
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils import data

# %%
cohort = data.init_cohort()

# %%
data.REPO_DATA_DIR
# Out:
# '/home/tavi/melanoma-reanalysis/data'

# %%
df_clinical = pd.read_excel(path.join(data.REPO_DATA_DIR, "clinical.xlsx"), skiprows=1)

# %%
df_clinical = df_clinical[df_clinical.Age.apply(lambda age: type(age) == int)]

# %%
df_clinical.reset_index(drop=True, inplace=True)

# %%
def get_digits(s):
    return "".join(c for c in s if c.isdigit())

# %%
df_clinical["patient_id"] = df_clinical["Study ID"].apply(lambda id: get_digits(id))

# %%
df_clinical["is_benefit"] = df_clinical["Response duration (weeks)"] > 24

# %%
df_clinical.is_benefit.sum()
# Out:
# 37

# %%
df_clinical.sort("Study ID")
# Out:
# /home/tavi/miniconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#        Study ID Age Gender Primary Melanoma type M stage Priors^  \
# 2       CR0095*  74      M             cutaneous     M1b       2
# 25     CR04885*  49      F             cutaneous    IIIc       0
# 26    CR06670^^  79      F             cutaneous    IIIc       0
# 0       CR1509*  54      F             cutaneous     M1c       1
# 27     CR22640*  71      M             cutaneous     M1c       1
# 5       CR3665*  70      M             cutaneous     M1b       1
# 3       CR4880*  63      M               unknown     M1b       2
# 28      CR6126*  66      F             cutaneous     M1b       1
# 29     CR6161^^  81      M             cutaneous     M1b       0
# 4       CR7623*  62      M             cutaneous     M1c       3
# 1       CR9306*  65      M             cutaneous     M1c       2
# ...

# %%
df_ucla = pd.read_excel(path.join(data.REPO_DATA_DIR, "original_validation.xlsx"),
                         sheetname="ucla")

# %%
df_mskcc.columns
# Out:
# Index([u'Valid set?', u'Sample ID', u'Notes ',
#        u'Yr of Diagnosis of Advanced Melanoma', u'Age at start of ipi',
#        u'Gender', u'Melanoma type', u'M stage at start of ipi',
#        u'Prior cytotoxic or IL-2 therapies', u'LDH at ipi start',
#        u'BRAF/NRAS status', u'Date of 1st ipi', u'Date of last ipi',
#        u'Ipi dosing (mg/kg)', u'Ipi Schedule', u'Biopsy date',
#        u'Biopsy Sample Site', u'Largest Dimension of Biopsied Tumor Sample',
#        u'Biopsy Type', u'Death or date of censure ', u'24-wk response',
#        u'Date of Progression or Censure', u'Response duration (days)',
#        u'Response duration (weeks)'],
#       dtype='object')

# %%
df_mskcc["os"] = df_mskcc["Death or date of censure "] - df_mskcc["Date of 1st ipi"]

# %%
df_mskcc.columns
# Out:
# Index([u'Valid set?', u'Sample ID', u'Notes ',
#        u'Yr of Diagnosis of Advanced Melanoma', u'Age at start of ipi',
#        u'Gender', u'Melanoma type', u'M stage at start of ipi',
#        u'Prior cytotoxic or IL-2 therapies', u'LDH at ipi start',
#        u'BRAF/NRAS status', u'Date of 1st ipi', u'Date of last ipi',
#        u'Ipi dosing (mg/kg)', u'Ipi Schedule', u'Biopsy date',
#        u'Biopsy Sample Site', u'Largest Dimension of Biopsied Tumor Sample',
#        u'Biopsy Type', u'Death or date of censure ', u'24-wk response',
#        u'Date of Progression or Censure', u'Response duration (days)',
#        u'Response duration (weeks)'],
#       dtype='object')

# %%
df_mskcc.rename({"Date of Progression or Censure": "is_progressed",
                 "Response duration (days)": "pfs",
                 "Death or date of censure": "deceased",
                 ""
# Out:
#     Valid set?            Sample ID  \
# 0            1             CRNR2472
# 1            1             CRNR4941
# 2            1              LSD4691
# 3            1              LSD4744
# 4            1              LSD0167
# 5            1               NR4631
# 6            1               NR4045
# 7            1               CR6126
# 8            1             CRNR0244
# 9            1              LSD3484
# 10           1            LSDNR1120
# 11           1            LSDNR1650
# 12           1               NR9449
# 13           1               NR9521
# 14           1               NR9705
# 15           2              LSD2057
# 16           2        LSDNR_PE_9298
# 17           2  LSD6819-complicated
# 18           2            LSDNR3086
# 19           2           CR_PE_6161
# 20           2               NR6689
# 21           2               NR2137
# 22           2           NR_PE_6721
# 23           2               NR8815
# 24           2               NR9445
# ...
