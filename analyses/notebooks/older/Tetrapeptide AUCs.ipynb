# %%
# %load_ext autoreload
# %autoreload 2

import sys 
from os import getcwd, path, environ
sys.path.append(path.dirname(getcwd()))
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd
# %matplotlib inline

# %%
import dill

# %%
from utils import data

# %%
cohort = data.init_cohort(four_callers=False)
                          #biopsy_time="pre",
                          #non_discordant=True)
# Out:
# {'dataframe_hash': -1756190467427032844,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}

# %%
from utils.aucs import Data
# Out:
# /home/tavi/miniconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /home/tavi/miniconda2/lib/python2.7/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
import six

# %%
from six import string_types

# %%
df = pd.DataFrame({"a": ["a"]})

# %%
df[df.a.apply(lambda s: )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-98db31f5102b> in <module>()
# ----> 1 df[isinstance(df.a, str)]
#
# /home/tavi/miniconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /home/tavi/miniconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /home/tavi/miniconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /home/tavi/miniconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3539
#    3540             if not isnull(item):
# -> 3541                 loc = self.items.get_loc(item)
#    3542             else:
#    3543                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /home/tavi/miniconda2/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4443)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4289)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13733)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13687)()
#
# KeyError: False

# %%
df_kmers = cohort.load_tetrapeptides()
# Out:
# Using saved IEDB data at /home/tavi/melanoma-reanalysis/data/iedb_tcell_data_6_10_15.csv
# Filtering on homo sap (col Epitope Source Organism Name): 161844 to 147504 elements
# Filtering on allergen (col Epitope Source Molecule Name): 147504 to 132235 elements
# Filtering on tuberculosis (col Epitope Source Organism Name): 132235 to 106516 elements

# %%
from utils.aucs import Predict, Data

# %%
data = Data(cohort, df_kmers)

# %%
predict = Predict(data)

# %%
len(cohort)
# Out:
# 64

# %%
#%%capture
aucs = predict.run()
# Out:
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': u'0.4.0',
#                              u'numpy': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'1.11.2',
#                              u'pandas': u'0.0.6',
#                              u'mhctools': u'0.19.1',
#                              u'pyensembl': u'0.4.0',
#                              u'numpy': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': u'0.19.1',
#                              u'pyensembl': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'1.0.3',
#                              u'scipy': u'0.0.6',
#                              u'mhctools': u'0.18.1',
#                              u'topiary': u'0.4.0',
#                              u'numpy': u'0.1.0',
#                              u'varcode': u'1.11.2',
#                              u'pandas': u'0.5.10'}}
# u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': u'0.19.1',
#                              u'pyensembl': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'1.0.3',
#                              u'scipy': u'0.0.6',
#                              u'mhctools': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.5.10'}}
# u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': u'0.1.0',
#                              u'varcode': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.5.10'}}
# u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'0.5.10'}}
# u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.11.2',
#                              u'pandas': u'1.0.3',
#                              u'scipy': u'0.19.1',
#                              u'pyensembl': u'0.18.1',
#                              u'topiary': u'1.0.3',
#                              u'scipy': u'0.1.0',
#                              u'varcode': u'0.18.1',
#                              u'topiary': u'0.5.10'}}
# u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': u'0.1.0',
#                              u'varcode': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.5.10'}}
# u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.19.1',
#                              u'pyensembl': u'0.0.6',
#                              u'mhctools': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'0.0.6',
#                              u'mhctools': u'1.0.3',
#                              u'scipy': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': u'1.11.2',
#                              u'pandas': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.19.1',
#                              u'pyensembl': u'0.0.6',
#                              u'mhctools': u'1.0.3',
#                              u'scipy': u'0.4.0',
#                              u'numpy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'1.11.2',
#                              u'pandas': u'0.5.10'}}
# u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': u'0.5.10'}}
# {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': u'0.5.10'}}
# {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': u'1.0.3',
#                              u'scipy': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.18.1',
#                              u'topiary': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': u'0.4.0',
#                              u'numpy': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'1.11.2',
#                              u'pandas': u'0.0.6',
#                              u'mhctools': u'0.19.1',
#                              u'pyensembl': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.18.1',
#                              u'topiary': u'0.5.10'}}
# u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.18.1',
#                              u'topiary': u'0.5.10'}}
# u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': u'0.18.1',
#                              u'topiary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': u'1.11.2',
#                              u'pandas': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.19.1',
#                              u'pyensembl': u'0.0.6',
#                              u'mhctools': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.4.0',
#                              u'numpy': u'0.5.10'}}
# u'1.11.2',
#                              u'pandas': {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.19.1',
#                              u'pyensembl': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.0.3',
#                              u'scipy': u'1.11.2',
#                              u'pandas': u'0.18.1',
#                              u'topiary': u'0.19.1',
#                              u'pyensembl': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# u'1.0.3',
#                              u'scipy': {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'0.18.1',
#                              u'topiary': u'1.11.2',
#                              u'pandas': u'0.1.0',
#                              u'varcode': u'0.19.1',
#                              u'pyensembl': u'0.5.10'}}
# u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': u'0.0.6',
#                              u'mhctools': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# {'dataframe_hash': -4996782079397876856,
#  'provenance_file_summary': {u'cohorts': u'0.4.2+1.g1b8048a.dirty',
#                              u'isovar': u'0.0.6',
#                              u'mhctools': u'0.4.0',
#                              u'numpy': u'1.11.2',
#                              u'pandas': u'0.19.1',
#                              u'pyensembl': u'1.0.3',
#                              u'scipy': u'0.18.1',
#                              u'topiary': u'0.1.0',
#                              u'varcode': u'0.5.10'}}
# Signature length: 373
# Training size: 48
# Signature length: 566
# Training size: 48
# Signature length: 910
# Training size: 48
# Signature length: 142
# Training size: 48
# Signature length: 459
# Training size: 48
# Signature length: 347
# Training size: 48
# Signature length: 398
# Training size: 48
# Signature length: 713
# Training size: 48
# Signature length: 587
# Training size: 48
# Signature length: 449
# Training size: 48
# Signature length: 623
# Training size: 48
# Signature length: 432
# Training size: 48
# Signature length: 777
# Training size: 48
# Signature length: 722
# Training size: 48
# Signature length: 418
# Training size: 48
# Signature length: 584
# Training size: 48
# Signature length: 1183
# Training size: 48
# Signature length: 828
# Training size: 48
# Signature length: 1224
# Training size: 48
# Signature length: 1556
# Training size: 48
# Signature length: 1079
# Training size: 48
# Signature length: 1253
# Training size: 48
# Signature length: 1107
# Training size: 48
# Signature length: 737
# Training size: 48
# Signature length: 631
# Training size: 48
# Signature length: 1084
# Training size: 48
# Signature length: 983
# Training size: 48
# Signature length: 1009
# Training size: 48
# Signature length: 2347
# Training size: 48
# Signature length: 1514
# Training size: 48

# %%
import numpy as np
np.mean(aucs)
# Out:
# 0.58879536850318592
